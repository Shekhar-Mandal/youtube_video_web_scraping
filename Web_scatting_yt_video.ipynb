# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time



driver = webdriver.Chrome()

driver.get(f"https://www.youtube.com/watch?v=nILY9FSj-nU/")

# %%
import numpy as np


# /html/body/ytd-app/div[1]/ytd-page-manager/ytd-watch-flexy/div[5]/div[1]/div/div[2]/div[11]/ytd-watch-next-secondary-results-renderer/div[2]/ytd-compact-video-renderer[1]/div[1]/div/div[1]/a/h3/span
# /html/body/ytd-app/div[1]/ytd-page-manager/ytd-watch-flexy/div[5]/div[1]/div/div[2]/div[11]/ytd-watch-next-secondary-results-renderer/div[2]/ytd-compact-video-renderer[2]/div[1]/div/div[1]/a/h3/span
title_of_video=[]
views=[]
durations=[]


for i in range(1,30):
    try:
        title=driver.find_element(By.XPATH,f'/html/body/ytd-app/div[1]/ytd-page-manager/ytd-watch-flexy/div[5]/div[1]/div/div[2]/div[11]/ytd-watch-next-secondary-results-renderer/div[2]/ytd-compact-video-renderer[{i}]/div[1]/div/div[1]/a/h3/span').text
        title_of_video.append(title)
        print(title)
    except:
        title_of_video.append(np.nan)
    try:
        views_of_video=driver.find_element(By.XPATH,f'/html/body/ytd-app/div[1]/ytd-page-manager/ytd-watch-flexy/div[5]/div[1]/div/div[2]/div[11]/ytd-watch-next-secondary-results-renderer/div[2]/ytd-compact-video-renderer[{i}]/div[1]/div/div[1]/a/div/ytd-video-meta-block/div[1]/div[2]/span[1]').text
        views.append(views_of_video)
        print(views_of_video)
    except:
        views.append(np.nan)  
    try:
        duration_of_video=driver.find_element(By.XPATH,f'/html/body/ytd-app/div[1]/ytd-page-manager/ytd-watch-flexy/div[5]/div[1]/div/div[2]/div[11]/ytd-watch-next-secondary-results-renderer/div[2]/ytd-compact-video-renderer[{i}]/div[1]/div/div[1]/a/div/ytd-video-meta-block/div[1]/div[2]/span[2]').text
        durations.append(duration_of_video)
        print(duration_of_video)
    except:
        duration.append(np.nan)
# Out:
# Arijit Singh Top 4 Songs | Arijit Singh Song | TG CREATION #arijitsinghsong
# 3.4M views
# 2 years ago
# Kk All Time Hits| Evergreen hits of KK |Jukebox KK | Romantic and love songs
# 8.5M views
# 4 years ago
# New Bollywood songs||Best of Arijit Singh song||Hindi songs
# 2.1M views
# 2 months ago
# Top 20 Bollywood Romance | Audio Jukebox | Best Hindi Love Songs | Romantic Bollywood Hits
# 4.4M views
# 3 weeks ago
# Best of Arijit Singh - Full Album | 50 Super Hit Songs | 3+ Hours Non-Stop
# 14M views
# 1 year ago
# Best Of Javed Ali | TOP 5 | Aa Jao Meri Tamanna, Deewana Kar Raha Hai, Ek Din Teri Raaho Mein, Guzar
# 6.3M views
# 2 years ago
# Romantic Hits By Jubin Nautiyal | Audio Jukebox | Latest Hindi Romantic Songs | T-Series
# 44M views
# 4 years ago
# Best of sushant singh rajput|arijit singh best songs|ssr best songs|latest arijit singh songs#music
# 4.6M views
# 1 year ago
# Track List JukeBox | Arjit Singh 2024 | Jukebox | #arjitsingh #hindi #songs #youtube #youtubevideo
# ...

# %% [markdown]
# # conbvert the lists intpo the dataframe

# %%
#!pip install pandas 

import pandas as pd

dicts={'title':title_of_video,'views':views,'durations':durations}
dicts
# Out:
# {'title': ['Arijit Singh Top 4 Songs | Arijit Singh Song | TG CREATION #arijitsinghsong',
#   'Kk All Time Hits| Evergreen hits of KK |Jukebox KK | Romantic and love songs',
#   'New Bollywood songs||Best of Arijit Singh song||Hindi songs',
#   'Top 20 Bollywood Romance | Audio Jukebox | Best Hindi Love Songs | Romantic Bollywood Hits',
#   'Best of Arijit Singh - Full Album | 50 Super Hit Songs | 3+ Hours Non-Stop',
#   'Best Of Javed Ali | TOP 5 | Aa Jao Meri Tamanna, Deewana Kar Raha Hai, Ek Din Teri Raaho Mein, Guzar',
#   'Romantic Hits By Jubin Nautiyal | Audio Jukebox | Latest Hindi Romantic Songs | T-Series',
#   'Best of sushant singh rajput|arijit singh best songs|ssr best songs|latest arijit singh songs#music',
#   'Track List JukeBox | Arjit Singh 2024 | Jukebox | #arjitsingh #hindi #songs #youtube #youtubevideo',
#   'Best of KK | kk songs | Juke box | Best Bollywood songs of kk | Kk hit songs |',
# ...

# %%
df=pd.DataFrame(dicts)

# %%
df
# Out:
#                                                 title       views  \
# 0   Arijit Singh Top 4 Songs | Arijit Singh Song |...  3.4M views
# 1   Kk All Time Hits| Evergreen hits of KK |Jukebo...  8.5M views
# 2   New Bollywood songs||Best of Arijit Singh song...  2.1M views
# 3   Top 20 Bollywood Romance | Audio Jukebox | Bes...  4.4M views
# 4   Best of Arijit Singh - Full Album | 50 Super H...   14M views
# 5   Best Of Javed Ali | TOP 5 | Aa Jao Meri Tamann...  6.3M views
# 6   Romantic Hits By Jubin Nautiyal | Audio Jukebo...   44M views
# 7   Best of sushant singh rajput|arijit singh best...  4.6M views
# 8   Track List JukeBox | Arjit Singh 2024 | Jukebo...  628K views
# 9   Best of KK | kk songs | Juke box | Best Bollyw...   14M views
# 10  The Melodies Hits of Arijit Singh Bollywood Ro...   41M views
# 11  Best Of Papon song // papon hindi romantic son...  1.8M views
# 12  Best of Arijit Singh l Arijit Singh hit songs ...  426K views
# ...

# %%
df.to_csv('Youtube_video_music_file.csv')

# %%
# Convert DataFrame to JSON and save to a file
df.to_json('Youtube_video_music_file.json', orient='records', lines=False)
